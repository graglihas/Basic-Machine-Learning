# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PolynomialFeatures

# %%
X = np.arange(1, 11).reshape(10, 1)
Y = np.array([10, 80, 17, 130, 6, 0, 0, 50, 100,1]).reshape(10, 1)

# %%
plt.figure(figsize=(12,10))
sns.regplot(x=X,y=Y)

# %%
deg=9
Poly=PolynomialFeatures(degree=deg)
X_Poly=Poly.fit_transform(X)
plr=LinearRegression()
plr.fit(X_Poly,Y)
# Out:
# array([[ 0.00000000e+00,  7.57607979e+04, -7.98132352e+04,
#          4.48125371e+04, -1.50183741e+04,  3.15397826e+03,
#         -4.18997294e+02,  3.42031885e+01, -1.56571532e+00,
#          3.07625361e-02]])

# %%
plt.figure(figsize=(12,10))
plt.scatter(X,Y,color='blue')
XX = np.arange(0.0, 10.0, 0.1)
yy=0
for i in range (deg+1):
    yy_ =   plr.coef_[0][i]*np.power(XX, i)
    yy = yy + yy_
yy = yy + plr.intercept_
plt.plot(XX, yy, '-r' )
plt.ylim(-20,150)
# Out:
# (-20.0, 150.0)
